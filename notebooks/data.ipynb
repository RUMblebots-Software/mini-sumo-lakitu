# %%
import os

drive_path = "G:\\Shared drives\\RB\\2025-2026\\Spring 2026\\Software\\MiniSumoDataset"

# Change the current working directory to your Google Drive folder
os.chdir(drive_path)

# Verify the current working directory
print(f"Current working directory: {os.getcwd()}")

# List files in the directory to confirm access
print("Files in directory:", os.listdir())
# Out:
# Current working directory: G:\Shared drives\RB\2025-2026\Spring 2026\Software\MiniSumoDataset
# Files in directory: ['README.txt', 'testing', 'training', 'info.labels']
